# %%
import wfdb
import os

# CẤU HÌNH CẦN CẬP NHẬT
WFDB_DATA_DIR = r"D:\Python\data-ppg-ecg\MATLAB_preprocessing\data\data_MIMIC" # Đảm bảo đúng
record_name = 'bidmc06' # Chỉ cần kiểm tra một record

try:
    record = wfdb.rdrecord(os.path.join(WFDB_DATA_DIR, record_name), smooth_frames=True)
    
    # IN RA TÊN TẤT CẢ CÁC KÊNH TRONG HEADER
    print("\n✅ TÊN CÁC KÊNH THỰC TẾ TRONG FILE LÀ:")
    print(record.sig_name)
    
except Exception as e:
    print(f"Lỗi khi đọc file bidmc04: {e}")
# Out:
# ✅ TÊN CÁC KÊNH THỰC TẾ TRONG FILE LÀ:
# ['RESP,', 'ABP,', 'CVP,', 'PLETH,', 'II,', 'V,', 'AVR,']
